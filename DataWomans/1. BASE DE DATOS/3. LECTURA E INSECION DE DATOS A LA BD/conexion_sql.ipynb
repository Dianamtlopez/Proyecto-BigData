# %%
# Se Instala la libreria para conectar
# !pip install sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in c:\users\diana\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (2.0.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\diana\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from sqlalchemy) (4.4.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\diana\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from sqlalchemy) (2.0.2)

# %%
# Se importan las librerias
import pandas as pd
from sqlalchemy import create_engine

# %%
# Importar y cargar el archivo csv
df = pd.read_csv('airbnb-listings.csv', sep = ';', index_col= 'ID', na_values='#N/D')

# %%
# Borrado de las columnas que no se usaran
df.drop(columns = ['Listing Url', 'Scrape ID', 'Last Scraped','Name', 'Summary', 'Space', 'Description', 
                   'Experiences Offered', 'Host Verifications', 'Street', 'Neighborhood Overview', 
                   'Notes', 'Transit', 'Access', 'Interaction', 'House Rules', 'Thumbnail Url', 
                   'Medium Url', 'Picture Url', 'XL Picture Url', 'Host URL', 'Host Name', 'Host Since', 
                   'Host Location', 'Host About', 'Host Response Time', 'Host Acceptance Rate', 
                   'Host Thumbnail Url', 'Host Picture Url', 'Host Neighbourhood', 'Neighbourhood',
                   'City', 'State', 'Smart Location', 'Country Code', 'Country', 'Bed Type',  
                   'Amenities', 'Square Feet', 'Security Deposit', 'Cleaning Fee', 'Calendar Updated', 
                   'Has Availability', 'Availability 30', 'Availability 60', 'Availability 90', 'Availability 365', 
                   'Calendar last Scraped', 'Last Review', 'First Review', 'License', 'Jurisdiction Names', 
                   'Calculated host listings count'], inplace = True)

# %%
# Se establece la conexión
engine = create_engine("postgresql://postgres:Jpablo20@localhost:5432/airbnb-listings")
conn = engine.connect()

# %%
# Se envía el dataframe a la base de datos
df.to_sql("data", con=engine, schema='Data_Womans_Company', if_exists="replace")
# Out:
# 252

# %%
# Leer los datos de la base de datos y crear un dataframe 
# (Verifico que haya quedado guardada la informacion)
df1 = pd.read_sql_table("data", conn, schema='Data_Womans_Company')  
df1
# Out:
#              ID    Host ID  Host Response Rate  Host Listings Count  \
# 0      15141125   96019257               100.0                  2.0
# 1       9470166    9885245               100.0                 13.0
# 2      17444981  118059488               100.0                  1.0
# 3       3284565    1892467               100.0                  3.0
# 4        499911    2467212               100.0                  1.0
# ...         ...        ...                 ...                  ...
# 14775  15694640    3773809               100.0                  1.0
# 14776  17475363   78570341               100.0                  1.0
# 14777  17584727  102947901               100.0                162.0
# 14778   6453584    5637692               100.0                  3.0
# 14779  14286839   84307851                60.0                  1.0
#
#        Host Total Listings Count  Neighbourhood Cleansed  \
# 0                            2.0             Embajadores
# 1                           13.0             Embajadores
# 2                            1.0             Embajadores
# 3                            3.0             Embajadores
# 4                            1.0             Embajadores
# ...                          ...                     ...
# 14775                        1.0           el Fort Pienc
# 14776                        1.0  la Dreta de l'Eixample
# 14777                      162.0  la Dreta de l'Eixample
# 14778                        3.0          Alexanderplatz
# 14779                        1.0       la Marina de Port
#
#       Neighbourhood Group Cleansed Zipcode     Market   Latitude  ...  \
# 0                           Centro   28005     Madrid  40.407453  ...
# 1                           Centro   28012     Madrid  40.408316  ...
# 2                           Centro   28012     Madrid  40.413722  ...
# 3                           Centro   28012     Madrid  40.411263  ...
# 4                           Centro   28012     Madrid  40.412556  ...
# ...                            ...     ...        ...        ...  ...
# 14775                     Eixample   08013  Barcelona  41.399336  ...
# 14776                     Eixample   08008  Barcelona  41.394654  ...
# 14777                     Eixample   08010  Barcelona  41.388179  ...
# 14778                        Mitte   10117     Berlin  52.527760  ...
# 14779               Sants-Montjuïc   08038  Barcelona  41.364782  ...
#
#        Review Scores Accuracy Review Scores Cleanliness Review Scores Checkin  \
# 0                        10.0                      10.0                  10.0
# 1                         8.0                       8.0                   9.0
# 2                         9.0                      10.0                   9.0
# 3                         9.0                       9.0                  10.0
# 4                        10.0                      10.0                  10.0
# ...                       ...                       ...                   ...
# 14775                    10.0                      10.0                  10.0
# 14776                     9.0                      10.0                   9.0
# 14777                     NaN                       NaN                   NaN
# 14778                     9.0                      10.0                  10.0
# 14779                     9.0                       9.0                   9.0
#
#        Review Scores Communication  Review Scores Location  \
# 0                             10.0                    10.0
# 1                              9.0                     9.0
# 2                             10.0                    10.0
# 3                             10.0                     9.0
# 4                             10.0                    10.0
# ...                            ...                     ...
# 14775                         10.0                    10.0
# 14776                          9.0                     9.0
# 14777                          NaN                     NaN
# 14778                         10.0                    10.0
# 14779                          9.0                     9.0
#
#        Review Scores Value  Cancellation Policy  Reviews per Month  \
# 0                     10.0             moderate               5.11
# 1                      8.0               strict               5.88
# 2                     10.0             moderate               6.18
# 3                      9.0               strict               0.19
# 4                     10.0               strict               1.39
# ...                    ...                  ...                ...
# 14775                 10.0             flexible               3.66
# 14776                  9.0             flexible               3.00
# 14777                  NaN      super_strict_30                NaN
# 14778                 10.0             moderate               0.21
# 14779                  9.0             moderate               4.43
#
#                                    Geolocation  \
# 0       40.40745268477803, -3.7079954754432634
# 1        40.40831556101927, -3.705006385704201
# 2      40.413722014584295, -3.7068231186536718
# 3      40.411263372718054, -3.6973054373712886
# 4        40.41255625665078, -3.701155364799422
# ...                                        ...
# 14775      41.3993357950806, 2.178007212000945
# 14776    41.39465435237872, 2.1625016321279538
# 14777   41.388179279378136, 2.1714668704754914
# 14778     52.5277599586111, 13.395542104209248
# 14779   41.364781648798875, 2.1390828598519382
#
#                                                 Features
# 0      Host Is Superhost,Host Has Profile Pic,Host Id...
# 1      Host Has Profile Pic,Host Identity Verified,Re...
# 2      Host Has Profile Pic,Host Identity Verified,Re...
# 3      Host Has Profile Pic,Host Identity Verified,Is...
# 4      Host Is Superhost,Host Has Profile Pic,Host Id...
# ...                                                  ...
# 14775  Host Has Profile Pic,Host Identity Verified,Is...
# 14776  Host Has Profile Pic,Host Identity Verified,Is...
# 14777  Host Has Profile Pic,Requires License,Instant ...
# 14778        Host Has Profile Pic,Host Identity Verified
# 14779  Host Has Profile Pic,Requires License,Instant ...
#
# [14780 rows x 36 columns]

# %%
# Desconectar de la base de datos
try:
    engine.dispose()
except Exception as e:
    print(e)
